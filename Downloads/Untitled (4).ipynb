# %%
import pandas as pd

df1 = pd.DataFrame({ [1, 2, 3], 
              [4, 5, 6],
              [7, 8, 9]})
df2 = pd.DataFrame({ [1, 2, 3],
                    [4, 5, 6],
            [7, 8, 9]})
df3 = pd.DataFrame({[1, 2, 3],
                    [4, 5, 6],
                    [7, 8, 9]})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_17/2984008252.py in <module>
#       3 df1 = pd.DataFrame({ [1, 2, 3],
#       4               [4, 5, 6],
# ----> 5               [7, 8, 9]})
#       6 df2 = pd.DataFrame({ [1, 2, 3],
#       7             [4, 5, 6],
#
# TypeError: unhashable type: 'list'

# %%
df1
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
DF= pd.DataFrame({"df1" : [df1],
                  "df2" : [df2],
                  "df3" : [df3]})

# %%
DF
# Out:
#                                            df1  \
# 0     A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9
#
#                                            df2  \
# 0     D  E  F
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9
#
#                                            df3
# 0     G  H  I
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
DF2 = pd.DataFrame({"df" : [df1, df2, df3]})

# %%
DF2
# Out:
#                                             df
# 0     A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9
# 1     D  E  F
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9
# 2     G  H  I
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9
